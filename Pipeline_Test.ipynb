# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Chu7zpah/Sourcecode-Handwriting-Analysis/master/CSVResult/Final_ABCDEFGH.csv")
print(df)
# Out:
#       inline_NO_brace  inline_YES_brace  ...  YES_binary_YES  Programmer
# 0                   0                 0  ...              27           A
# 1                   1                 0  ...               6           A
# 2                   1                 0  ...               6           A
# 3                   0                 0  ...              12           A
# 4                   0                 0  ...               0           A
# ...               ...               ...  ...             ...         ...
# 1244                0                 0  ...              54           H
# 1245                0                 0  ...              38           H
# 1246                0                 9  ...              29           H
# 1247                0                 0  ...               5           H
# 1248                0                 0  ...              31           H
#
# [1249 rows x 15 columns]

# %%
data = df.drop(columns=['Programmer'])
label = df['Programmer']

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Perceptron
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier



scaler_dict = {}
scaler_dict['std_scaler'] = StandardScaler()
scaler_dict['minmax_scaler'] = MinMaxScaler()

model_dict = {}
model_dict['logistic_regression_ovr'] = LogisticRegression(multi_class='ovr', max_iter=1000)
model_dict['logistic_regression_multinomial'] = LogisticRegression(multi_class='multinomial', max_iter=1000)
model_dict['perceptron'] = Perceptron(max_iter=1000)
model_dict['decision_tree'] = tree.DecisionTreeClassifier()
model_dict['knn'] = KNeighborsClassifier(n_neighbors=10)
model_dict['gaussian_nb'] = GaussianNB()
#model_dict['multinomial_nb'] = MultinomialNB()
model_dict['bernoulli_nb'] = BernoulliNB()
model_dict['random_forest'] = RandomForestClassifier()
model_dict['one_vs_one'] = OneVsOneClassifier(SVC())
model_dict['one_vs_rest'] = OneVsRestClassifier(SVC())
model_dict['mlp'] = MLPClassifier(max_iter=5000)
  
for scaler in scaler_dict.keys():
  for model in model_dict.keys():
    print(scaler)
    print(model)
    pipe = Pipeline([('scaler', scaler_dict[scaler]), ('model', model_dict[model])])

    scores = cross_val_score(pipe, X_train, y_train, cv=5)
    print(scores)
    print(scores.mean())

    pipe.fit(X_train, y_train)

    y_preds = pipe.predict(X_test)

    print(accuracy_score(y_test, y_preds))
# Out:
# std_scaler
# logistic_regression_ovr
# [0.57       0.535      0.565      0.56       0.61809045]
# 0.5696180904522613
# 0.564
# std_scaler
# logistic_regression_multinomial
# [0.605      0.58       0.6        0.605      0.64321608]
# 0.6066432160804021
# 0.584
# std_scaler
# perceptron
# [0.5        0.535      0.495      0.53       0.53266332]
# 0.518532663316583
# 0.504
# std_scaler
# decision_tree
# [0.74       0.73       0.725      0.785      0.76884422]
# 0.7497688442211056
# 0.72
# std_scaler
# knn
# [0.71       0.65       0.69       0.705      0.70854271]
# 0.6927085427135677
# 0.684
# std_scaler
# gaussian_nb
# [0.495      0.52       0.52       0.505      0.49246231]
# 0.5064924623115579
# 0.436
# std_scaler
# bernoulli_nb
# [0.49       0.47       0.48       0.49       0.53266332]
# 0.4925326633165829
# 0.48
# std_scaler
# random_forest
# [0.84       0.795      0.83       0.87       0.88442211]
# 0.8438844221105528
# 0.812
# std_scaler
# one_vs_one
# [0.505      0.505      0.525      0.49       0.54773869]
# 0.5145477386934674
# 0.552
# std_scaler
# one_vs_rest
# [0.715      0.63       0.65       0.645      0.68341709]
# 0.6646834170854271
# 0.652
# std_scaler
# mlp
# [0.8        0.75       0.765      0.75       0.81909548]
# 0.7768190954773869
# 0.804
# minmax_scaler
# logistic_regression_ovr
# [0.445      0.43       0.43       0.435      0.42713568]
# 0.433427135678392
# 0.4
# minmax_scaler
# logistic_regression_multinomial
# [0.435      0.435      0.44       0.44       0.42713568]
# 0.435427135678392
# 0.4
# minmax_scaler
# perceptron
# [0.365      0.395      0.43       0.335      0.50753769]
# 0.40650753768844217
# 0.496
# minmax_scaler
# decision_tree
# [0.72       0.68       0.705      0.77       0.73869347]
# 0.7227386934673368
# 0.732
# minmax_scaler
# knn
# [0.705      0.625      0.635      0.665      0.68844221]
# 0.6636884422110553
# 0.672
# minmax_scaler
# gaussian_nb
# [0.525      0.515      0.52       0.505      0.50753769]
# 0.5145075376884422
# 0.46
# minmax_scaler
# bernoulli_nb
# [0.695      0.66       0.67       0.72       0.73869347]
# 0.6967386934673367
# 0.672
# minmax_scaler
# random_forest
# [0.86       0.81       0.835      0.855      0.85929648]
# 0.8438592964824121
# 0.82
# minmax_scaler
# one_vs_one
# [0.495      0.52       0.55       0.54       0.55276382]
# 0.5315527638190956
# 0.548
# minmax_scaler
# one_vs_rest
# [0.7        0.635      0.65       0.66       0.71356784]
# 0.671713567839196
# 0.668
# minmax_scaler
# mlp
# [0.785      0.74       0.775      0.77       0.79899497]
# 0.7737989949748744
# 0.796

# %%
# 위에 다른 Model들은 1000번 정도면 충분히 Converge, MLP만 Converge가 되지 않아서 5000으로 조정 (Warning 발생)
