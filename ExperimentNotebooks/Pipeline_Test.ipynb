# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Chu7zpah/Sourcecode-Handwriting-Analysis/master/CSVResult/Final_ABCDEFGH.csv")
print(df)
# Out:
#       inline_NO_brace  inline_YES_brace  ...  YES_binary_YES  Programmer
# 0                   0                 0  ...              27           A
# 1                   1                 0  ...               6           A
# 2                   1                 0  ...               6           A
# 3                   0                 0  ...              12           A
# 4                   0                 0  ...               0           A
# ...               ...               ...  ...             ...         ...
# 1244                0                 0  ...              54           H
# 1245                0                 0  ...              38           H
# 1246                0                 9  ...              29           H
# 1247                0                 0  ...               5           H
# 1248                0                 0  ...              31           H
#
# [1249 rows x 15 columns]

# %%
data = df.drop(columns=['Programmer'])
label = df['Programmer']

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Perceptron
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier



scaler_dict = {}
scaler_dict['std_scaler'] = StandardScaler()
scaler_dict['minmax_scaler'] = MinMaxScaler()

model_dict = {}
model_dict['logistic_regression_ovr'] = LogisticRegression(multi_class='ovr', max_iter=1000)
model_dict['logistic_regression_multinomial'] = LogisticRegression(multi_class='multinomial', max_iter=1000)
model_dict['perceptron'] = Perceptron(max_iter=1000)
model_dict['decision_tree'] = tree.DecisionTreeClassifier()
model_dict['knn'] = KNeighborsClassifier(n_neighbors=10)
model_dict['gaussian_nb'] = GaussianNB()
#model_dict['multinomial_nb'] = MultinomialNB()
model_dict['bernoulli_nb'] = BernoulliNB()
model_dict['random_forest'] = RandomForestClassifier()
model_dict['one_vs_one'] = OneVsOneClassifier(SVC())
model_dict['one_vs_rest'] = OneVsRestClassifier(SVC())
model_dict['mlp'] = MLPClassifier(max_iter=5000)

X_train, X_test, y_train, y_test = train_test_split(data, label, test_size= 0.2)

for scaler in scaler_dict.keys():
  for model in model_dict.keys():
    print(scaler)
    print(model)
    pipe = Pipeline([('scaler', scaler_dict[scaler]), ('model', model_dict[model])])

    scores = cross_val_score(pipe, X_train, y_train, cv=5)
    print(scores)
    print(scores.mean())

    pipe.fit(X_train, y_train)

    y_preds = pipe.predict(X_test)

    print(accuracy_score(y_test, y_preds))
# Out:
# std_scaler
# logistic_regression_ovr
# [0.56      0.61      0.59      0.56      0.6281407]
# 0.5896281407035175
# 0.624
# std_scaler
# logistic_regression_multinomial
# [0.605      0.65       0.645      0.57       0.63316583]
# 0.6206331658291456
# 0.648
# std_scaler
# perceptron
# [0.46       0.505      0.55       0.635      0.57286432]
# 0.5445728643216081
# 0.58
# std_scaler
# decision_tree
# [0.725      0.74       0.715      0.695      0.72361809]
# 0.7197236180904522
# 0.764
# std_scaler
# knn
# [0.705      0.655      0.695      0.66       0.63819095]
# 0.6706381909547738
# 0.668
# std_scaler
# gaussian_nb
# [0.47       0.545      0.53       0.535      0.52763819]
# 0.5215276381909548
# 0.536
# std_scaler
# bernoulli_nb
# [0.475      0.54       0.485      0.485      0.51256281]
# 0.49951256281407036
# 0.504
# std_scaler
# random_forest
# [0.83       0.82       0.84       0.82       0.83417085]
# 0.8288341708542714
# 0.844
# std_scaler
# one_vs_one
# [0.515      0.56       0.53       0.535      0.54773869]
# 0.5375477386934674
# 0.572
# std_scaler
# one_vs_rest
# [0.625      0.66       0.685      0.62       0.67839196]
# 0.653678391959799
# 0.688
# std_scaler
# mlp
# [0.77      0.745     0.79      0.73      0.7638191]
# 0.7597638190954774
# 0.748
# minmax_scaler
# logistic_regression_ovr
# [0.425      0.445      0.47       0.45       0.47236181]
# 0.45247236180904515
# 0.436
# minmax_scaler
# logistic_regression_multinomial
# [0.425      0.455      0.46       0.435      0.47738693]
# 0.45047738693467343
# 0.432
# minmax_scaler
# perceptron
# [0.37       0.39       0.445      0.53       0.51256281]
# 0.44951256281407037
# 0.448
# minmax_scaler
# decision_tree
# [0.735      0.76       0.725      0.705      0.71859296]
# 0.7287185929648242
# 0.744
# minmax_scaler
# knn
# [0.67       0.665      0.665      0.68       0.63819095]
# 0.6636381909547738
# 0.66
# minmax_scaler
# gaussian_nb
# [0.48       0.55       0.53       0.535      0.52763819]
# 0.5245276381909548
# 0.54
# minmax_scaler
# bernoulli_nb
# [0.66       0.675      0.715      0.65       0.69346734]
# 0.6786934673366833
# 0.712
# minmax_scaler
# random_forest
# [0.845      0.81       0.86       0.82       0.84924623]
# 0.8368492462311558
# 0.844
# minmax_scaler
# one_vs_one
# [0.54      0.585     0.545     0.55      0.5678392]
# 0.5575678391959799
# 0.596
# minmax_scaler
# one_vs_rest
# [0.635      0.64       0.685      0.62       0.66834171]
# 0.6496683417085427
# 0.688
# minmax_scaler
# mlp
# [0.77       0.745      0.805      0.73       0.73366834]
# 0.7567336683417085
# 0.768

# %%
# 위에 다른 Model들은 1000번 정도면 충분히 Converge, MLP만 Converge가 되지 않아서 5000으로 조정 (Warning 발생)
