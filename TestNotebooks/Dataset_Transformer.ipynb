# %%
'''
    [ Sourcecode Handwriting Extraction Preprocessor ]
        Remove Strings ("[REMOVED]") and Comments (//[REMOVED], /* [REMOVED] */)
        Made by Chu7zpah
'''
import re

string_exist = re.compile(r'"(.*?)"')   # RE that checks is there any string(" ~ ") in code
comment_space = re.compile(r'//\s\S+.*')
comment_NO_space = re.compile(r'//\S+.*')
comment_multiline_in_one = re.compile(r'/\*\s\S+.*\s\*/')
comment_multiline_start = re.compile(r'/\*')
comment_multiline_end = re.compile(r'\*/')

f = open('./test.c', 'r')
raw_line_list = f.readlines()
no_string_line_list = []
cleaned_line_list = []

for raw_line in raw_line_list:
    # Exclude Strings
    if string_exist.search(raw_line) is None:
        no_string_line_list.append(raw_line)
    elif string_exist.search(raw_line) is not None:
        for string in string_exist.findall(raw_line):       
            no_string_line_list.append(raw_line.replace(f'"{string}"', '""')) 

flag = 0
for no_string_line in no_string_line_list:
    # Multi Line Comments Checking
    if flag:
        if comment_multiline_end.search(no_string_line) is not None:
            flag = 0
        else:
            continue

    # Exclude One Line Comments
    if comment_space.search(no_string_line) is not None:
        for comment in comment_space.findall(no_string_line):
            cleaned_line_list.append(no_string_line.replace(f'{comment}', f'// {comment[3]}'))
    elif comment_NO_space.search(no_string_line) is not None:
        for comment in comment_NO_space.findall(no_string_line):
            cleaned_line_list.append(no_string_line.replace(f'{comment}', f'//{comment[2]}'))
    elif comment_multiline_in_one.search(no_string_line) is not None:
        for comment in comment_multiline_in_one.findall(no_string_line):
            cleaned_line_list.append(no_string_line.replace(f'{comment}', '/* */'))
    # Exclude Multi Line Comments
    elif comment_multiline_start.search(no_string_line) is not None:
        cleaned_line_list.append(no_string_line)
        flag = 1
    else:
        cleaned_line_list.append(no_string_line)

f.close()

# %%
'''
    [ Sourcecode Handwriting Characteristics Extractor ]
        From Source Code(C Based) -> CSV
        Made by Chu7zpah
      
      <Features>
        Feature 1. Brace('{') Habits
            case 1: 'FUNCTION(){'       (inline brace with NO Space)
            case 2: 'FUNCTION() {'      (inline brace with Space)
            case 3: 'FUNCTION()         (next line brace)
                     {'          

        Feature 2. Comment('//' or '/* */') Habits
            case 1: '//COMMENT'         ('//' with NO Space)
            case 2: '// COMMENT'        ('//' with Space)
            case 3: '/* COMMENT */'     (using '/* */')

        Feature 3. Parenthesis('(') Habits
            case 1: '{if/switch/while/for}('    (Reserved words with No Space)
            case 2: '{if/switch/while/for} ('   (Reserved words with Space)

        Feature 4. Unary Operator(Type Casting) Habits
            case 1: '(TYPE)VARIABLE'        (Type Casting with NO Space)
            case 2: '(TYPE) VARIABLE'       (Type Casting with Space)
        
        Feature 5. Binary Operator(Arithmetic, Assignments, etc.) Habits
            ex) '+' Operator
            case 1: 'VARIABLE+VARIABLE'     (NO Space && Binary Operator && NO Space)
            case 2: 'VARIABLE+ VARIABLE'    (NO Space && Binary Operator && Space)
            case 3: 'VARIABLE +VARIABLE'    (Space && Binary Operator && NO Space)
            case 4: 'VARIABLE + VARIABLE'   (Space && Binary operator && Space)
'''
features_list = [   
                    'inline_NO_brace', 'inline_YES_brace', 'nextline_brace', # Feature 1. Brace
                    'double_backslash_NO_Space', 'double_backslash_YES_Space', 'single_backslash_asterisk', # Feature 2. Comment
                    'NO_parenthesis', 'YES_parenthesis', # Feature 3. Parenthesis
                    'unary_NO_space', 'unary_YES_space', # Feature 4. Unary Operator
                    'NO_binary_NO', 'NO_binary_YES', 'YES_binary_NO', 'YES_binary_YES'  # Feature 5. Binary Opeartor
                ]

print("[Feature Columns]")
print(features_list)


# <Extracted Feature Data Dictionary>
features_data_dictionary = {}
for feature in features_list:       # Initialize counting variables
    features_data_dictionary[f'{feature}_count'] = 0
print("\n[initialized Feature data dictionary]")
print(features_data_dictionary)


# <Feature RE Expressions>
inline_NO_brace = re.compile('[\)|\S]\{')       # 'Function(){' (RE: '\)\{')  OR  'struct{' (RE: \S\{)
inline_YES_brace = re.compile('[\)|\S]\s+\{')   # 'Function() {' (RE: '\)\s+\{')  OR  'struct {' (RE: \S\s+\{)
nextline_brace = re.compile('\s*\{')            # 'ENTER' + '{' (RE: '\s*\{')

double_backslash_NO_Space = re.compile('//\S')      # '//Comment'
double_backslash_YES_Space = re.compile('//\s+\S')  # '// Comment'
single_backslash_asterisk = re.compile('/\*')       # '/* Comment */'

NO_parenthesis = re.compile('if\(|switch\(|for\(|while\(')                  # '{if/switch/while/for}('
YES_parenthesis = re.compile('if\s+\(|switch\s+\(|for\s+\(|while\s+\(')     # '{if/switch/while/for} ('


# Type list for Unary Operator(Type Casting)
type_list = ['char', 'short', 'int', 'long', 'long long', 
            'unsigned char', 'unsigned short', 'unsigned int', 'unsigned long',
            'float', 'double', 'long double']

# Operator list for Binary Opeartors
operator_list = [   '\+', '-', '\*', '/', '%',    # Arithmetic
                    '=', '\+=', '-=', '\*=', '/=', '%=', 
                    '&=', '^=', '\|=', '<<=', '>>=', '>>>=', # Assignment
                    '==', '!=', '>', '<', '>=', '<=',       # Comparison
                    '&&', '\|\|',    # Logical
                    '>>', '<<', '>>>', # Shift
                    ';', ',', '",']  # ';' in for loop, ',' in function call


# <Analyzing Source Code>
for line in cleaned_line_list:
    # Preprocessing (Exclude Strings)  
    if string_exist.search(line) is not None:
        for string in string_exist.findall(line):       
            line = line.replace(f'"{string}"', '""')
    

    # Feature Extraction
    #   (Feature 1 - Brace)
    if inline_NO_brace.search(line) is not None:
        features_data_dictionary['inline_NO_brace_count'] += 1
    elif inline_YES_brace.search(line) is not None:
        features_data_dictionary['inline_YES_brace_count'] += 1
    elif nextline_brace.search(line) is not None:
        features_data_dictionary['nextline_brace_count'] += 1

    #   (Feature 2 - Comment)
    if double_backslash_NO_Space.search(line) is not None:
        features_data_dictionary['double_backslash_NO_Space_count'] += 1
    elif double_backslash_YES_Space.search(line) is not None:
        features_data_dictionary['double_backslash_YES_Space_count'] += 1
    elif single_backslash_asterisk.search(line) is not None:
        features_data_dictionary['single_backslash_asterisk_count'] += 1

    #   (Feature 3 - Parenthesis)
    if NO_parenthesis.search(line) is not None:
        features_data_dictionary['NO_parenthesis_count'] += 1
    elif YES_parenthesis.search(line) is not None:
        features_data_dictionary['YES_parenthesis_count'] += 1

    #   (Feature 4 - Unary Operator)
    for data_type in type_list:
        unary_NO_space = re.compile(rf'\({data_type}\)\S')
        unary_YES_space = re.compile(rf'\({data_type}\)\s+\S')
        
        if unary_NO_space.search(line) is not None:
            features_data_dictionary['unary_NO_space_count'] += 1
        elif unary_YES_space.search(line) is not None:
            features_data_dictionary['unary_YES_space_count'] += 1

    #   (Feature 5 - Binary Operator)
    for operator in operator_list:
        NO_binary_NO = re.compile(rf'(\w|\)|\]){operator}(\w|\(|\[)')
        NO_binary_YES = re.compile(rf'(\w|\)|\]){operator}\s+(\w|\(|\[)')
        YES_binary_NO = re.compile(rf'(\w|\)|\])\s+{operator}(\w|\(|\[)')
        YES_binary_YES = re.compile(rf'(\w|\)|\])\s+{operator}\s+(\w|\(|\[)')

        if NO_binary_NO.search(line) is not None:
            features_data_dictionary['NO_binary_NO_count'] += 1
            print("NONO", line)
        elif NO_binary_YES.search(line) is not None:
            features_data_dictionary['NO_binary_YES_count'] += 1
            print("NOYES", line, "OPERATOR: ", operator)
        elif YES_binary_NO.search(line) is not None:
            features_data_dictionary['YES_binary_NO_count'] += 1
            print("YESNO", line)
        elif YES_binary_YES.search(line) is not None:
            features_data_dictionary['YES_binary_YES_count'] += 1
            print("YESYES", line)

brace_total =         features_data_dictionary['inline_NO_brace_count'] \
                    + features_data_dictionary['inline_YES_brace_count'] \
                    + features_data_dictionary['nextline_brace_count']
comment_total =       features_data_dictionary['double_backslash_NO_Space_count'] \
                    + features_data_dictionary['double_backslash_YES_Space_count'] \
                    + features_data_dictionary['single_backslash_asterisk_count']
parenthesis_total =   features_data_dictionary['NO_parenthesis_count'] \
                    + features_data_dictionary['YES_parenthesis_count']
unary_total =         features_data_dictionary['unary_NO_space_count'] \
                    + features_data_dictionary['unary_YES_space_count']
binary_total =        features_data_dictionary['NO_binary_NO_count'] \
                    + features_data_dictionary['NO_binary_YES_count'] \
                    + features_data_dictionary['YES_binary_NO_count'] \
                    + features_data_dictionary['YES_binary_YES_count']

print("\n[Calculated Feature data dictionary]")
print(features_data_dictionary)

print("\n[Total Values]")
print("Brace:", brace_total)
print("comment:", comment_total)
print("parenthesis:", parenthesis_total)
print("unary:", unary_total)
print("binary:", binary_total)
# Out:
# [Feature Columns]
# ['inline_NO_brace', 'inline_YES_brace', 'nextline_brace', 'double_backslash_NO_Space', 'double_backslash_YES_Space', 'single_backslash_asterisk', 'NO_parenthesis', 'YES_parenthesis', 'unary_NO_space', 'unary_YES_space', 'NO_binary_NO', 'NO_binary_YES', 'YES_binary_NO', 'YES_binary_YES']
#
# [initialized Feature data dictionary]
# {'inline_NO_brace_count': 0, 'inline_YES_brace_count': 0, 'nextline_brace_count': 0, 'double_backslash_NO_Space_count': 0, 'double_backslash_YES_Space_count': 0, 'single_backslash_asterisk_count': 0, 'NO_parenthesis_count': 0, 'YES_parenthesis_count': 0, 'unary_NO_space_count': 0, 'unary_YES_space_count': 0, 'NO_binary_NO_count': 0, 'NO_binary_YES_count': 0, 'YES_binary_NO_count': 0, 'YES_binary_YES_count': 0}
# YESNO #include <stdio.h>
#
# NONO     int a=0; // 2
#
# YESYES     if(a == 0) {    // 2
#
# NOYES         t= (float) a;  //1
#  OPERATOR:  =
# YESYES         t = 0;  //3
#
# NOYES     for (int i= 0 ; i < 5 ; i++)
#  OPERATOR:  =
# YESYES     for (int i= 0 ; i < 5 ; i++)
#
# YESYES     for (int i= 0 ; i < 5 ; i++)
#
# YESYES         if(a == 0){
#
# YESYES             d = (float)a;
#
#
# [Calculated Feature data dictionary]
# {'inline_NO_brace_count': 3, 'inline_YES_brace_count': 1, 'nextline_brace_count': 3, 'double_backslash_NO_Space_count': 6, 'double_backslash_YES_Space_count': 3, 'single_backslash_asterisk_count': 4, 'NO_parenthesis_count': 3, 'YES_parenthesis_count': 2, 'unary_NO_space_count': 1, 'unary_YES_space_count': 1, 'NO_binary_NO_count': 1, 'NO_binary_YES_count': 2, 'YES_binary_NO_count': 1, 'YES_binary_YES_count': 6}
#
# [Total Values]
# Brace: 7
# comment: 13
# parenthesis: 5
# unary: 2
# binary: 10

# %%
'''
    Making a CSV File
'''
import csv

double_quote_feature_list = []
for feature in features_list:
    double_quote_feature_list.append(feature.replace(f'{feature}', f'"{feature}"')) 
double_quote_feature_list.append(r'"Programmer"')
print(double_quote_feature_list)

csv_file = open('./optest.csv', 'w', encoding='utf-8')
wr = csv.writer(csv_file, quotechar="'")    # quotechar = '' (If not, " becomes """)
wr.writerow(double_quote_feature_list)

csv_file.close()
# Out:
# ['"inline_NO_brace"', '"inline_YES_brace"', '"nextline_brace"', '"double_backslash_NO_Space"', '"double_backslash_YES_Space"', '"single_backslash_asterisk"', '"NO_parenthesis"', '"YES_parenthesis"', '"unary_NO_space"', '"unary_YES_space"', '"NO_binary_NO"', '"NO_binary_YES"', '"YES_binary_NO"', '"YES_binary_YES"', '"Programmer"']

# %%
import os

def search(dirname):
    try:
        filenames = os.listdir(dirname)
        for filename in filenames:
            full_filename = os.path.join(dirname, filename)
            if os.path.isdir(full_filename):
                search(full_filename)
            else:
                ext = os.path.splitext(full_filename)[-1]
                if ext == '.c':
                    print(full_filename)
    except PermissionError:
        pass

search('C:/Users/Nyx_24/Desktop/Dataset')
# Out:
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\ec.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\error.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\eval.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\exec-operand.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\exec.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\libc.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\ns.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\object.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\opregion.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\os_methods.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\pc-bios.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\pci.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\pm.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\resource.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\sci.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\timer.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\variable.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(18)lai\vsnprintf.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\acpi.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\alloc.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\apic.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\cmdline.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\cmem.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\cpu.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\cstring.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\dev.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\devfs.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\echfs.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\elf.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\exceptions.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\fat32.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\fd.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\fs.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\gdt.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\hostname.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\hpet.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\ide.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\idt.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\iso9660.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\klib.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\madt.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\main.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\mass_storage.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\nvme.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\panic.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\part.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\pci.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\pic.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\pic_8259.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\pipe.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\pit.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\pmm.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\qemu.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\rand.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\sata.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\scsi.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\smp.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\streams.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\syscalls.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\task.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\time.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\trace.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\tty.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\urm.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\usb.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\userspace.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\vbe.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\vfs.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\vmm.c
# C:/Users/Nyx_24/Desktop/Dataset\A\(52)qword\xhci.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\alignof.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\alloca.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\arith.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\asm.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\atomic.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\attribute.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\bitfield.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\builtin.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\cast.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\codegen.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\commonsym.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\compat.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\complit.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\const.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\constexpr.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\control.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\decl.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\enum.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\extern.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\float.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\function.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\generic.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\hashmap.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\initializer.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\line.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\literal.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\macro.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\main.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\offsetof.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\parse.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\pointer.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\pragma-once.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\preprocess.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\sizeof.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\stdhdr.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\string.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\strings.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\struct.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\tls.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\tokenize.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\type.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\typedef.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\typeof.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\unicode (2).c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\unicode.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\union.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\usualconv.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\varargs.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\variable.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(50)chibicc-main\vla.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\align.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\arith.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\array.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\assign.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\bitop.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\buffer.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\builtin.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\cast.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\comp.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\constexpr.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\control.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\conversion.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\cpp.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\debug.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\decl.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\dict.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\encoding.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\enum.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\error.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\extern.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\file.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\float.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\funcargs.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\function.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\gen.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\generic.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\global.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\import.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\includeguard.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\initializer.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\int.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\iso646.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\lex (2).c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\lex.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\line.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\literal.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\macro.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\main.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\map.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\noreturn.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\number.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\oldstyle.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\parse.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\path.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\pointer.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\scope.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\set.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\sizeof.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\staticassert.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\stmtexpr.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\struct.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\testmain.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\type.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\typeof.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\union.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\usualconv.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\utiltest.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\varargs.c
# C:/Users/Nyx_24/Desktop/Dataset\B\(59)8cc-master\vector.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\arithmicoperations.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\arrayHW 9 in progress.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\arrayINclassGrade.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\ArrayStudy.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\assignment1.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\Assignment10.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\assignment2.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\assignment2revised.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\assignment7.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\assignment_7.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\checkpoint4_mpg.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\convertTemps.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\example1.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\exampleCounterN.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\factorials_checkpoint4.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\final.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\findavegrades2.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\functions.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\funtions.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\gradesArray.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\gradesforclass.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\gradesforclassavg.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\helloworld.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\homework10roughdraft.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\homework8.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\hw10.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\hw10inProgress.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\hw5.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\hw5avgTestgrades.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\hw5inclass.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\hw5inclassSample.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\hw6_partA.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\hw6_partB.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\hw6_partC.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\hw6_partC_final.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\hw6_partD.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\HW8inProgress.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\hw9.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\hw9final (2).c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\hw9FINAL.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\inclass.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\input.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\logicalOperators.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\nested_for_loops.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\numbers.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\operators.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\periIncheslenghtsquare.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\piggybank.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\practiceOCT25.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\practiceProblem1.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\printAVGdiff4numbers.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\printAVGof4numbers.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\problem3Function.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\Quiz 6.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\radiusandcircumfrence.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\revisedhwdivisible.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\sample 1 hw in class.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\shipping.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\shortcutOperators.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\slide10_7Problems.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\Switch (2)fromwill.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\Switch.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\SwitchlowNumOnly.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\switchpractice.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\temp_conversion.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\test.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\test1.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\testGradeScores.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\threeprices.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\updateArrayStudy.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\whileCountMultiples.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\whileloops2.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\whileloops3.c
# C:/Users/Nyx_24/Desktop/Dataset\C\(74)c-programming-master\while_loops.c

# %%
import os

programmer_list = ['A', 'B', 'C']

for programmer in programmer_list:
    for (path, dir, files) in os.walk(f'C:/Users/Nyx_24/Desktop/Dataset/{programmer}'):
        for filename in files:
            ext = os.path.splitext(filename)[-1]
            if ext == '.c':
                full_directory = path + '/' + filename
                full_directory = full_directory.replace('\\', '/')
                print(full_directory)
# Out:
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/ec.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/error.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/eval.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/exec-operand.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/exec.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/libc.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/ns.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/object.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/opregion.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/os_methods.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/pc-bios.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/pci.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/pm.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/resource.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/sci.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/timer.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/variable.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(18)lai/vsnprintf.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/acpi.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/alloc.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/apic.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/cmdline.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/cmem.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/cpu.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/cstring.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/dev.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/devfs.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/echfs.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/elf.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/exceptions.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/fat32.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/fd.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/fs.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/gdt.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/hostname.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/hpet.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/ide.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/idt.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/iso9660.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/klib.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/madt.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/main.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/mass_storage.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/nvme.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/panic.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/part.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/pci.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/pic.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/pic_8259.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/pipe.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/pit.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/pmm.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/qemu.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/rand.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/sata.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/scsi.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/smp.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/streams.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/syscalls.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/task.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/time.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/trace.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/tty.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/urm.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/usb.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/userspace.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/vbe.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/vfs.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/vmm.c
# C:/Users/Nyx_24/Desktop/Dataset/A/(52)qword/xhci.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/alignof.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/alloca.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/arith.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/asm.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/atomic.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/attribute.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/bitfield.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/builtin.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/cast.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/codegen.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/commonsym.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/compat.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/complit.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/const.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/constexpr.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/control.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/decl.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/enum.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/extern.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/float.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/function.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/generic.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/hashmap.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/initializer.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/line.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/literal.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/macro.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/main.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/offsetof.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/parse.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/pointer.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/pragma-once.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/preprocess.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/sizeof.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/stdhdr.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/string.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/strings.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/struct.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/tls.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/tokenize.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/type.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/typedef.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/typeof.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/unicode (2).c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/unicode.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/union.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/usualconv.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/varargs.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/variable.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(50)chibicc-main/vla.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/align.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/arith.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/array.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/assign.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/bitop.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/buffer.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/builtin.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/cast.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/comp.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/constexpr.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/control.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/conversion.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/cpp.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/debug.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/decl.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/dict.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/encoding.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/enum.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/error.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/extern.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/file.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/float.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/funcargs.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/function.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/gen.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/generic.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/global.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/import.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/includeguard.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/initializer.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/int.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/iso646.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/lex (2).c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/lex.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/line.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/literal.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/macro.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/main.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/map.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/noreturn.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/number.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/oldstyle.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/parse.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/path.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/pointer.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/scope.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/set.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/sizeof.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/staticassert.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/stmtexpr.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/struct.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/testmain.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/type.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/typeof.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/union.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/usualconv.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/utiltest.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/varargs.c
# C:/Users/Nyx_24/Desktop/Dataset/B/(59)8cc-master/vector.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/arithmicoperations.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/arrayHW 9 in progress.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/arrayINclassGrade.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/ArrayStudy.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/assignment1.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/Assignment10.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/assignment2.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/assignment2revised.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/assignment7.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/assignment_7.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/checkpoint4_mpg.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/convertTemps.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/example1.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/exampleCounterN.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/factorials_checkpoint4.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/final.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/findavegrades2.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/functions.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/funtions.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/gradesArray.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/gradesforclass.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/gradesforclassavg.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/helloworld.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/homework10roughdraft.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/homework8.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/hw10.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/hw10inProgress.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/hw5.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/hw5avgTestgrades.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/hw5inclass.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/hw5inclassSample.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/hw6_partA.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/hw6_partB.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/hw6_partC.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/hw6_partC_final.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/hw6_partD.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/HW8inProgress.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/hw9.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/hw9final (2).c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/hw9FINAL.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/inclass.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/input.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/logicalOperators.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/nested_for_loops.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/numbers.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/operators.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/periIncheslenghtsquare.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/piggybank.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/practiceOCT25.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/practiceProblem1.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/printAVGdiff4numbers.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/printAVGof4numbers.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/problem3Function.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/Quiz 6.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/radiusandcircumfrence.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/revisedhwdivisible.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/sample 1 hw in class.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/shipping.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/shortcutOperators.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/slide10_7Problems.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/Switch (2)fromwill.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/Switch.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/SwitchlowNumOnly.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/switchpractice.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/temp_conversion.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/test.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/test1.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/testGradeScores.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/threeprices.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/updateArrayStudy.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/whileCountMultiples.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/whileloops2.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/whileloops3.c
# C:/Users/Nyx_24/Desktop/Dataset/C/(74)c-programming-master/while_loops.c
